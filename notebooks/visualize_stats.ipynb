# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# attack_type = 'none'
datasets = 'pokec_n pokec_z'.split()
# stats = 'homophily community'.split()
df_results = pd.DataFrame()
for dataset in datasets:
    for attack_type in 'random dice sacide none'.split():
        c_attack_type = attack_type
        df_current = pd.read_csv(f'../results/stats-homophily-{dataset}-{c_attack_type}.csv')
        df_current['dataset'] = dataset
        df_current['attack_type'] = attack_type
        df_results = pd.concat([df_results, df_current], ignore_index=True)

# %%
for attack in df_results.attack_type.unique():
    row = df_results[df_results.attack_type == 'none']
    row['attack_type'] = attack
    df_results=df_results.append(row, ignore_index=True)
# Out:
# /home/hhussain/anaconda3/envs/fair/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for measure in 'label_homophily_macro sens_homophily_macro'.split():
    plt.figure()
    g = sns.FacetGrid(df_results, col='dataset')
    g.map(sns.lineplot,'ptb_rate', measure, 'attack_type')
    plt.legend()
    plt.savefig('../reports/figures/' + measure + '.png')
#     sns.lineplot(data=df_results, x='ptb_rate', hue='attack_type', y=measure)

# %%
# attack_type = 'none'
datasets = 'pokec_n pokec_z'.split()
# stats = 'homophily community'.split()
df_results = pd.DataFrame()
for dataset in datasets:
    for attack_type in 'dice sacide none'.split():
        c_attack_type = attack_type
        df_current = pd.read_csv(f'../results/stats-community-{dataset}-{c_attack_type}.csv')
        df_current['dataset'] = dataset
        df_current['attack_type'] = attack_type
        df_results = pd.concat([df_results, df_current], ignore_index=True)

# %%
for attack in df_results.attack_type.unique():
    row = df_results[df_results.attack_type == 'none']
    row['attack_type'] = attack
    df_results=df_results.append(row, ignore_index=True)
# Out:
# /home/hhussain/anaconda3/envs/fair/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for measure in 'community_label_correlation community_sens_correlation'.split():
    plt.figure()
    g = sns.FacetGrid(df_results, col='dataset')
    g.map(sns.lineplot,'ptb_rate', measure, 'attack_type')
    plt.legend()
    plt.savefig('../reports/figures/' + measure + '.png')
#     sns.lineplot(data=df_results, x='ptb_rate', hue='attack_type', y=measure)
